# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.getcwd()
os.chdir('C:\\Users\\swathi veldanda\\OneDrive\\Desktop\\Projectairbnb')
os.getcwd()
# Out:
# 'C:\\Users\\swathi veldanda\\OneDrive\\Desktop\\Projectairbnb'

# %%
df1=pd.read_csv('calendar.csv')
df1.head()
df1.groupby('listing_id')["price"].describe()
# Out:
#              count unique       top freq
# listing_id
# 1.080610e+05   365      1  $120.00   365
# 1.553050e+05   365     20  $119.00   141
# 1.568050e+05   365      2   $65.00   261
# 1.569260e+05   365      4   $26.00   196
# 1.605940e+05   365      1  $125.00   365
# ...            ...    ...       ...  ...
# 5.826310e+17   365      4  $189.00   261
# 5.826380e+17   365      6   $85.00   211
# 5.834330e+17   365    116   $95.00    14
# 5.838680e+17   365     10  $229.00    79
# 5.841920e+17   365      8  $299.00   351
#
# [2691 rows x 4 columns]

# %%
print(df1.shape)
df1=df1.drop_duplicates()
print(df1.shape)
# Out:
# (990610, 7)
# (990414, 7)

# %%
df2=pd.read_csv('listings.csv')
df2.head()
df2=df2.rename(columns={'id':'listing_id'})
df2.head()
# Out:
#    listing_id                          listing_url     scrape_id last_scraped  \
# 0    108061.0  https://www.airbnb.com/rooms/108061  2.022030e+13    3/20/2022
# 1    155305.0  https://www.airbnb.com/rooms/155305  2.022030e+13    3/20/2022
# 2    156805.0  https://www.airbnb.com/rooms/156805  2.022030e+13    3/20/2022
# 3    156926.0  https://www.airbnb.com/rooms/156926  2.022030e+13    3/20/2022
# 4    160594.0  https://www.airbnb.com/rooms/160594  2.022030e+13    3/20/2022
#
#                                                 name  \
# 0  Walk to stores/parks/downtown. Fenced yard/Pet...
# 1                 Cottage! BonPaul + Sharky's Hostel
# 2                  Private Room "Ader" at BPS Hostel
# 3             Mixed Dorm "Top Bunk #1" at BPS Hostel
# 4                                Historic Grove Park
#
#                                          description  \
# 0  Walk to town in ten minutes! Monthly rental in...
# 1  <b>The space</b><br />Private cottage located ...
# 2  <b>The space</b><br />Private Rooms at Bon Pau...
# 3  This is a top bunk in the mixed dorm room<br /...
# 4  Come enjoy the beautiful Grove Park neighborho...
#
#                                neighborhood_overview  \
# 0  I love my neighborhood! Its friendly, easy-goi...
# 1  We are within easy walk of pubs, breweries, mu...
# 2  Easy walk to pubs, cafes, bakery, breweries, l...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/41011975/0cdf...   320564
# 1  https://a0.muscache.com/pictures/8880711/cf38d...   746673
# 2  https://a0.muscache.com/pictures/23447d55-fa7e...   746673
# 3  https://a0.muscache.com/pictures/98f4e655-c4d6...   746673
# 4  https://a0.muscache.com/pictures/92433837/d340...   769252
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/320564  ...                        4.79
# 1  https://www.airbnb.com/users/show/746673  ...                        4.76
# 2  https://www.airbnb.com/users/show/746673  ...                        4.61
# 3  https://www.airbnb.com/users/show/746673  ...                        4.80
# 4  https://www.airbnb.com/users/show/769252  ...                        4.88
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   4.84                4.48     NaN                f
# 1                   4.93                4.53     NaN                t
# 2                   4.84                4.46     NaN                t
# 3                   4.78                4.79     NaN                t
# 4                   4.90                4.85     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              2                                           2
# 1                              7                                           1
# 2                              7                                           1
# 3                              7                                           1
# 4                              1                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            2
# 3                                            2
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.70
# 1                                           4              2.76
# 2                                           4              0.52
# 3                                           4              2.34
# 4                                           0              0.45
#
# [5 rows x 74 columns]

# %%
df2.columns
# Out:
# Index(['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
columns_needed=['listing_id','name','neighborhood_overview','host_id','host_name','host_since', 'host_location', 'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost','host_listings_count',
       'host_total_listings_count','host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
       'neighbourhood_cleansed','latitude',
       'longitude', 'property_type', 'room_type', 'accommodates',
       'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price','minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm', 'has_availability',
       'availability_30', 'availability_60', 'availability_90',
       'availability_365', 'number_of_reviews',
       'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'instant_bookable',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms', 'reviews_per_month' ]
df2=df2[columns_needed]

# %%
df3=pd.read_csv('reviews.csv')
df3.head()
print(df3.shape)
# Out:
# (244481, 6)

# %%
df3=df3.drop_duplicates()
print(df3.shape)
# Out:
# (244481, 6)

# %%
df23=pd.merge(df2,df3,on='listing_id',how=('outer'))
df23.head()
# Out:
#    listing_id                          listing_url     scrape_id last_scraped  \
# 0    108061.0  https://www.airbnb.com/rooms/108061  2.022030e+13    3/20/2022
# 1    108061.0  https://www.airbnb.com/rooms/108061  2.022030e+13    3/20/2022
# 2    108061.0  https://www.airbnb.com/rooms/108061  2.022030e+13    3/20/2022
# 3    108061.0  https://www.airbnb.com/rooms/108061  2.022030e+13    3/20/2022
# 4    108061.0  https://www.airbnb.com/rooms/108061  2.022030e+13    3/20/2022
#
#                                                 name  \
# 0  Walk to stores/parks/downtown. Fenced yard/Pet...
# 1  Walk to stores/parks/downtown. Fenced yard/Pet...
# 2  Walk to stores/parks/downtown. Fenced yard/Pet...
# 3  Walk to stores/parks/downtown. Fenced yard/Pet...
# 4  Walk to stores/parks/downtown. Fenced yard/Pet...
#
#                                          description  \
# 0  Walk to town in ten minutes! Monthly rental in...
# 1  Walk to town in ten minutes! Monthly rental in...
# 2  Walk to town in ten minutes! Monthly rental in...
# 3  Walk to town in ten minutes! Monthly rental in...
# 4  Walk to town in ten minutes! Monthly rental in...
#
#                                neighborhood_overview  \
# 0  I love my neighborhood! Its friendly, easy-goi...
# 1  I love my neighborhood! Its friendly, easy-goi...
# 2  I love my neighborhood! Its friendly, easy-goi...
# 3  I love my neighborhood! Its friendly, easy-goi...
# 4  I love my neighborhood! Its friendly, easy-goi...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/41011975/0cdf...   320564
# 1  https://a0.muscache.com/pictures/41011975/0cdf...   320564
# 2  https://a0.muscache.com/pictures/41011975/0cdf...   320564
# 3  https://a0.muscache.com/pictures/41011975/0cdf...   320564
# 4  https://a0.muscache.com/pictures/41011975/0cdf...   320564
#
#                                    host_url  ...  \
# 0  https://www.airbnb.com/users/show/320564  ...
# 1  https://www.airbnb.com/users/show/320564  ...
# 2  https://www.airbnb.com/users/show/320564  ...
# 3  https://www.airbnb.com/users/show/320564  ...
# 4  https://www.airbnb.com/users/show/320564  ...
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              2                                           2
# 1                              2                                           2
# 2                              2                                           2
# 3                              2                                           2
# 4                              2                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month         id  \
# 0                                           0               0.7   553741.0
# 1                                           0               0.7   683278.0
# 2                                           0               0.7   714889.0
# 3                                           0               0.7  1766157.0
# 4                                           0               0.7  2033065.0
#
#          date reviewer_id  reviewer_name  \
# 0   9/21/2011    822907.0  Pedro & Katie
# 1   11/1/2011    236064.0            Tim
# 2  11/13/2011   1382707.0          Shane
# 3   7/21/2012    416731.0         Brenda
# 4   8/19/2012   1858880.0        Lindsey
#
#                                             comments
# 0  Lisa is superb hostess, she will treat you lik...
# 1  This was a lovely little place walking distanc...
# 2  Lisa was very nice to work with.  However, we ...
# 3  I feel very lucky to have found this beautiful...
# 4  Great roomy little apartment, beautiful privat...
#
# [5 rows x 79 columns]

# %%
print(df3.shape)
print(df23.shape)
# Out:
# (244481, 6)
# (247159, 79)

# %%
df23.describe()
# Out:
#          listing_id     scrape_id       host_id  host_listings_count  \
# count  2.471590e+05  2.471590e+05  2.471590e+05        247150.000000
# mean   7.085885e+15  2.022030e+13  8.992418e+07             7.156917
# std    6.228613e+16  1.378870e+02  1.030838e+08            41.544355
# min    1.080610e+05  2.022030e+13  6.266700e+04             0.000000
# 25%    1.327431e+07  2.022030e+13  1.387467e+07             1.000000
# 50%    2.209562e+07  2.022030e+13  4.552277e+07             1.000000
# 75%    3.400982e+07  2.022030e+13  1.431414e+08             3.000000
# max    5.841920e+17  2.022030e+13  4.482893e+08           752.000000
#
#        host_total_listings_count  neighbourhood_cleansed  \
# count              247150.000000           247159.000000
# mean                    7.156917            28796.402320
# std                    41.544355               24.981785
# min                     0.000000            28704.000000
# 25%                     1.000000            28801.000000
# 50%                     1.000000            28804.000000
# 75%                     3.000000            28806.000000
# max                   752.000000            28806.000000
#
#        neighbourhood_group_cleansed       latitude      longitude  \
# count                           0.0  247159.000000  247159.000000
# mean                            NaN      35.580715     -82.558395
# std                             NaN       0.043862       0.044904
# min                             NaN      35.423420     -82.691050
# 25%                             NaN      35.568340     -82.590800
# 50%                             NaN      35.589590     -82.557590
# 75%                             NaN      35.605850     -82.529160
# max                             NaN      35.656090     -82.459420
#
#         accommodates  ...  review_scores_location  review_scores_value  \
# count  247159.000000  ...           246722.000000        246722.000000
# mean        3.846815  ...                4.893339             4.842976
# std         2.328194  ...                0.095853             0.122036
# min         1.000000  ...                1.000000             1.000000
# 25%         2.000000  ...                4.860000             4.800000
# 50%         4.000000  ...                4.910000             4.870000
# 75%         4.000000  ...                4.950000             4.920000
# max        16.000000  ...                5.000000             5.000000
#
#        license  calculated_host_listings_count  \
# count      0.0                   247159.000000
# mean       NaN                        4.592898
# std        NaN                       15.034831
# min        NaN                        1.000000
# 25%        NaN                        1.000000
# 50%        NaN                        1.000000
# 75%        NaN                        3.000000
# max        NaN                      114.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                247159.000000
# mean                                      4.215384
# std                                      15.067128
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     114.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                 247159.000000
# mean                                       0.350321
# std                                        1.124962
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       10.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count                                247159.000000      246723.000000
# mean                                      0.022427           4.576739
# std                                       0.283129           2.688618
# min                                       0.000000           0.010000
# 25%                                       0.000000           2.540000
# 50%                                       0.000000           4.010000
# 75%                                       0.000000           6.100000
# max                                       4.000000          15.560000
#
#                  id   reviewer_id
# count  2.469890e+05  2.469890e+05
# mean   1.145363e+17  1.267033e+08
# std    2.054473e+17  1.113552e+08
# min    4.094370e+05  6.100000e+01
# 25%    3.372508e+08  3.666260e+07
# 50%    6.112629e+08  9.243780e+07
# 75%    7.665812e+08  1.892693e+08
# max    5.869260e+17  4.497383e+08
#
# [8 rows x 44 columns]

# %%
##Customers have great room stay experiece with ratings approximately 4.9/5
##This represents Airbnb has more positive reviews than negative reviews
df23[['review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value'
      ]].describe()
# Out:
#        review_scores_rating  review_scores_accuracy  \
# count         246723.000000           246722.000000
# mean               4.887573                4.924462
# std                0.112912                0.085441
# min                0.000000                1.000000
# 25%                4.850000                4.900000
# 50%                4.920000                4.950000
# 75%                4.970000                4.980000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count              246722.000000          246722.000000
# mean                    4.906284               4.963689
# std                     0.111102               0.068675
# min                     1.000000               3.000000
# 25%                     4.870000               4.960000
# 50%                     4.950000               4.980000
# 75%                     4.980000               4.990000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                246722.000000           246722.000000
# mean                      4.951242                4.893339
# std                       0.081085                0.095853
# min                       2.000000                1.000000
# 25%                       4.940000                4.860000
# 50%                       4.970000                4.910000
# 75%                       4.990000                4.950000
# max                       5.000000                5.000000
#
#        review_scores_value
# count        246722.000000
# mean              4.842976
# std               0.122036
# min               1.000000
# 25%               4.800000
# 50%               4.870000
# 75%               4.920000
# max               5.000000

# %% [markdown]
# All service aspects have Positive Review
# Airbnb have various aspects of customer experience such as check-in experience, room cleanliness, location, communication, and also value.
#
# In the chart, all aspects also have positive rating business should maintain these effort to keep customers coming in
#
# There's still improvement to be made from the bad ratings We'll take a look at these bad reviews later and what kind of unpleasant experience they had during the stay

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 3)
fig.tight_layout()
ax[0, 0].hist(df23["review_scores_rating"]) #row=0, col=2
ax[0 ,0].set_title('Rating')
ax[0, 1].hist(df23["review_scores_accuracy"]) #row=0, col=0
ax[0, 1].set_title('accuracy')
ax[1, 0].hist(df23["review_scores_checkin"]) #row=1, col=0
ax[1, 0].set_title('Check In')
ax[0, 2].hist(df23["review_scores_cleanliness"]) #row=0, col=1
ax[0, 2].set_title('Cleanliness')
ax[1, 2].hist(df23["review_scores_communication"]) #row=1, col=1
ax[1, 2].set_title('Communication')
ax[1, 1].hist(df23["review_scores_location"]) #row=1, col=2
ax[1 ,1].set_title('Location')

plt.show()

# %%
#count missing values
df23['comments'].isnull().sum()
# Out:
# 213

# %% [markdown]
# There are 213 rows that have missing values and we fill it with blanks.
#
# If we did not perform Missing Value Treatment (MVT), performing word count will occur error.
#
# It's safe to fill it with blanks, since customer did not leave review about their stay.

# %%
import itertools
import collections

def convert(lst): 
    return ([i for item in lst for i in item.lower().split()]) 

all_words_review = convert(df23['comments'].fillna(""))

# %% [markdown]
# The texts also lowered to avoid overlapping words that have similar intention.
#
# Then, split each word to count their frequency

# %% [markdown]
# # Word Frequency

# %%
count_word = collections.Counter(all_words_review) #Count word frequency

clean_word_count = pd.DataFrame(count_word.most_common(5),
                             columns=['words', 'count'])

clean_word_count.head()
# Out:
#   words   count
# 0   and  535181
# 1   the  496057
# 2    to  352924
# 3     a  315991
# 4   was  272286

# %% [markdown]
# The word frequency runs well, but we cannot understand what these words mean.
#
# We wouldn't want these words showed up and we can remove them with nltk library

# %% [markdown]
# # Removing Stopwords
#
# Stopwords are common in any language.
#
# But we should remove them when analyzing text data, as this doesn't add much value for our analysis

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\swathi
# [nltk_data]     veldanda\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words(['english']))

# View a few words from the set
list(stop_words)[0:10]
# Out:
# ['couldn', 'myself', "isn't", 'itself', 'did', 'on', 'few', 'to', 'nor', 'i']

# %% [markdown]
#  stopwords should be removed from the data

# %%
words_review_cleaned = [word for word in all_words_review if word not in stop_words]
words_review_count = collections.Counter(words_review_cleaned)

word_review_count_df = pd.DataFrame(words_review_count.most_common(20),
                             columns=['words', 'count'])
words_review_cleaned
# Out:
# ['lisa',
#  'superb',
#  'hostess,',
#  'treat',
#  'like',
#  'family',
#  'provide',
#  'coziest',
#  'little',
#  'home',
#  'asheville',
#  'definitely',
#  'enhance',
#  'experience',
#  'magical',
#  'town!',
#  'like',
#  'eco-retreat,',
#  'private',
#  'sunny',
#  'apartment',
#  'neat',
#  'little',
#  'flat',
#  'need',
#  '3',
#  'people,',
#  'place',
#  'impeccable',
#  'lovely',
#  'neighborhood.',
#  'hardly',
#  'beat',
#  'one!',
#  'lovely',
#  'little',
#  'place',
#  'walking',
#  'distance',
#  'downtown.',
#  'lisa',
#  'responsive.',
#  'best',
#  'airbnb',
#  'experience',
#  'yet!',
#  'lisa',
#  'nice',
#  'work',
#  'with.',
#  'however,',
#  'realize',
#  'house',
#  'old.',
#  'normally',
#  'would',
#  'okay,',
#  'case,',
#  'meant',
#  'floor',
#  'us',
#  '(where',
#  'permanent',
#  'renters',
#  'lived)',
#  'squeaky.',
#  'first',
#  'night',
#  'stayed',
#  'there,',
#  'sleep',
#  'people',
#  'us',
#  'walking',
#  'around',
#  '3am.',
#  'hear',
#  'walking',
#  'around',
#  'next',
#  'night,',
#  'third',
#  'night.',
#  '<br/>the',
#  'apartment',
#  'cute',
#  'clean.',
#  'everything',
#  'needed,',
#  'even',
#  'back',
#  'yard',
#  'us',
#  'take',
#  'dog',
#  'walk',
#  'in.',
#  '<br/>if',
#  'go',
#  'winter,',
#  'heating',
#  'wall',
#  'heaters.',
#  'close',
#  'downtown',
#  'right',
#  'next',
#  'greenlife',
#  'grocery',
#  'store.',
#  'location',
#  'nice.',
#  'feel',
#  'lucky',
#  'found',
#  'beautiful',
#  'home',
#  'asheville.',
#  'quiet,',
#  'clean',
#  'well',
#  'thought',
#  "guest's",
#  'needs.',
#  'stayed',
#  'glorious',
#  'month',
#  'attending',
#  'classes',
#  'unca.',
#  'location',
#  'apartment',
#  'absolutely',
#  'perfect.',
#  'walked',
#  'campus',
#  'woods',
#  'everyday',
#  'walked',
#  'downtown',
#  'almost',
#  'often...i',
#  'could',
#  'anywhere',
#  'ten',
#  'minutes',
#  'loved',
#  '"home"',
#  'here.',
#  'peaceful',
#  'lush.',
#  "there's",
#  'nice',
#  'big',
#  'kitchen,',
#  'awesome',
#  'love',
#  'cook',
#  'beautiful',
#  'gardens',
#  'vegetables',
#  'herbs',
#  'use.',
#  'loved',
#  'bathroom,',
#  'like',
#  'suite',
#  'unto',
#  'itself,',
#  'huge',
#  'vanity',
#  'great',
#  'walk',
#  'shower.',
#  'also',
#  'thought',
#  'bed',
#  'comfortable',
#  'appreciated',
#  'good',
#  'quality',
#  'linens',
#  'pillows.',
#  'lisa',
#  'made',
#  'easy',
#  'feel',
#  'home.',
#  'gave',
#  'tour',
#  'town',
#  'showed',
#  'find',
#  'trail',
#  'unca',
#  'cool',
#  'bike',
#  'trails',
#  'too...let',
#  'borrow',
#  'bike,',
#  'really',
#  'nice.',
#  'wonderful',
#  'time,',
#  'definitely',
#  'come',
#  'back',
#  'highly',
#  'recommend',
#  'it!',
#  'excellent',
#  'every',
#  'way!',
#  'great',
#  'roomy',
#  'little',
#  'apartment,',
#  'beautiful',
#  'private',
#  'backyard',
#  'deck,',
#  'perfect',
#  'guests',
#  'dog',
#  'even',
#  'without.',
#  'lisa',
#  'friendly,',
#  'helpful',
#  'host,',
#  'would',
#  'stay',
#  'heartbeat.',
#  'lisa',
#  'great',
#  'host.',
#  'even',
#  'came',
#  'greet',
#  'us',
#  'pulled',
#  'drive',
#  'way.',
#  'apartment',
#  'clean',
#  'cozy.',
#  'short',
#  'walk',
#  'broadway',
#  'lexington',
#  'downtown',
#  'lot',
#  'restaurants',
#  'bars',
#  'located.',
#  'enjoyed',
#  'stay',
#  'definitely',
#  'back.',
#  'excellent',
#  'location',
#  'downtown.',
#  'needed',
#  'cooking',
#  'facilities',
#  'us,',
#  'understand',
#  'going',
#  'change.',
#  'david',
#  'great',
#  'guy,',
#  'really',
#  'enjoyed',
#  'stay',
#  'beautiful',
#  'house',
#  'creates',
#  'perfect',
#  'ambience',
#  'family',
#  'time.',
#  'slept',
#  'well,',
#  'enjoyed',
#  'local',
#  'walks,',
#  'convenient',
#  'visiting',
#  'daughter',
#  'university',
#  'nc',
#  'asheville.',
#  'easy',
#  'walks',
#  'great',
#  'food',
#  'entertainment.',
#  'much',
#  'appreciated.',
#  '-k',
#  '<br/>',
#  '<br/>ps',
#  'little',
#  'dog',
#  'welcome',
#  'too,',
#  'outdoor',
#  'run',
#  'appreciation',
#  'scooter',
#  'david',
#  '(scooter',
#  'sends',
#  'thanks,',
#  'too).',
#  'great',
#  'location,',
#  'good',
#  'price.',
#  'apartment',
#  'suited',
#  'needs',
#  'well.',
#  '5',
#  'month',
#  'old',
#  'son',
#  'left,',
#  'everything',
#  'worked',
#  'well.',
#  'going',
#  'bring',
#  'dog,',
#  'sure',
#  'accommodating',
#  'back',
#  'yard',
#  'would',
#  'be,',
#  'think',
#  'would',
#  'fine',
#  'big',
#  'back',
#  'yard.',
#  'place',
#  'super',
#  'cute',
#  'clean',
#  'great',
#  'location!',
#  'make',
#  'sure',
#  'bring',
#  'luxuries',
#  'might',
#  'need',
#  '-',
#  'soap,',
#  'shampoo,',
#  'coffee.',
#  'also,',
#  'futon',
#  'picute',
#  'replaced',
#  'couch,',
#  '2nd',
#  'bed',
#  'mattress',
#  'floor.',
#  'another',
#  'downside,',
#  'bathroom',
#  'bedroom,',
#  'anyone',
#  'sleeping',
#  'living',
#  'room',
#  'needs',
#  'go',
#  'bedroom.',
#  'really',
#  'ideal',
#  'two',
#  'people.',
#  'owners',
#  'live',
#  'pretty',
#  'thin',
#  'floors',
#  'hear',
#  'walking',
#  'around.',
#  'party',
#  'last',
#  'night',
#  'end',
#  'almost',
#  '5:00',
#  '-',
#  'get',
#  'sleep.',
#  'great',
#  'place',
#  'dogs',
#  'though.',
#  'yard',
#  'amazing',
#  'owners',
#  'really',
#  'nice.',
#  'wonderful',
#  'time',
#  'asheville!',
#  'house',
#  'centrally-located',
#  'beautifully',
#  'furnished.',
#  'lots',
#  'outdoor',
#  'space!',
#  'lisa',
#  'fantastic',
#  'host',
#  'helped',
#  'us',
#  'plan',
#  'weekend',
#  'stay.',
#  'would',
#  'highly',
#  'recommend',
#  'staying',
#  'would',
#  'stay',
#  'heartbeat',
#  'myself.',
#  'stayed',
#  "lisa/david's",
#  'place',
#  'long',
#  'bele',
#  'chere',
#  'weekend.',
#  'space',
#  'quirky',
#  'little',
#  'basement',
#  'nice',
#  'big',
#  'bathroom',
#  'gigantic',
#  'shower.',
#  'location',
#  'certainly',
#  'walkable',
#  'downtown',
#  'like',
#  'walk',
#  '(takes',
#  '15',
#  'min)',
#  'also',
#  'close',
#  'botanical',
#  'gardens',
#  'unca.',
#  '<br/>',
#  '<br/>the',
#  'back',
#  'yard',
#  'patio',
#  'nice',
#  'have,',
#  'giving',
#  'nice',
#  'view',
#  'adorable',
#  'neighborhood.',
#  'overall,',
#  'good',
#  'experience',
#  'lisa',
#  'responsive',
#  'helpful',
#  'stay.',
#  '<br/>',
#  '<br/>our',
#  'complaints',
#  'would',
#  'slightly',
#  'awkward',
#  'use',
#  'space',
#  'front',
#  'room',
#  'apartment,',
#  'change',
#  'furniture',
#  '(different',
#  'couch)',
#  'photos,',
#  'fact',
#  'bed',
#  'comfortable.',
#  'sweet',
#  'little',
#  'apartment,',
#  'clean,',
#  'good',
#  'light,',
#  'north',
#  'downtown',
#  'asheville.',
#  'nice',
#  'design',
#  'touches',
#  'throughout,',
#  'good',
#  'sized',
#  'bathroom.',
#  'worked',
#  'well',
#  'cooking',
#  'meals.',
#  'wi-fi',
#  'worked',
#  'well.',
#  'unit',
#  'could',
#  'use',
#  'tv',
#  'connection',
#  'microwave.',
#  'little',
#  'back',
#  'porch',
#  'huge',
#  'backyard',
#  'made',
#  'feel',
#  'like',
#  'home.',
#  'husband',
#  'architect',
#  'landlords',
#  'ourselves,',
#  'apartment',
#  'really',
#  'impressed.',
#  '<br/>',
#  '<br/>immediate',
#  'neighborhood',
#  'coffee',
#  'shop',
#  'grocery',
#  'stores,',
#  'good',
#  'walking',
#  'dog.',
#  'downtown',
#  'asheville',
#  'also',
#  'impressed',
#  'us',
#  'vibrant,',
#  'interesting',
#  'shops',
#  'restaurants,',
#  'larger',
#  'area',
#  'great:',
#  'biltmore',
#  'estate,',
#  'hiking',
#  'pisgah',
#  'national',
#  'forest,',
#  'christmount',
#  'black',
#  'mountain.',
#  'found',
#  'sweet',
#  'spot',
#  'last',
#  'minute',
#  'looking',
#  'place',
#  'decompress',
#  'wedding',
#  'disappoint.',
#  'lisa',
#  'thoughtful',
#  'planning',
#  'space',
#  'ease',
#  'use.',
#  'walk',
#  'shower',
#  'delightful.',
#  'slept',
#  'like',
#  'dead',
#  'queen',
#  'sized',
#  'bed',
#  'windows',
#  'open.',
#  'great',
#  'coffee',
#  'porch',
#  'am.',
#  'lisa',
#  'great',
#  'unobtrusive',
#  'yet',
#  'available',
#  'host.',
#  'please',
#  'check',
#  'place',
#  'next',
#  'time',
#  'want',
#  'walk',
#  'around',
#  'asheville',
#  '3',
#  'awesome',
#  'grocery',
#  'stores',
#  'couple',
#  'blocks',
#  'away!',
#  'thanks!',
#  'lisa',
#  'could',
#  'accommodating.',
#  'place',
#  'great,',
#  'backyard',
#  'lovely,',
#  'truly',
#  'close',
#  'everything!',
#  'wedding',
#  'weekend,',
#  'needed',
#  'needle',
#  '&',
#  'thread',
#  'iron,',
#  'lisa',
#  'produced',
#  'matter',
#  'minutes.',
#  'stay',
#  'here!',
#  'lovely',
#  'apartment',
#  '20',
#  'minutes',
#  'walking',
#  'bars',
#  'restaurants',
#  'downtown.',
#  'place',
#  'clean,',
#  'tidy',
#  'nicely',
#  'decorated.',
#  'stayed',
#  'two',
#  'nights',
#  ':(',
#  'lisa',
#  'helpful',
#  'pointed',
#  'couple',
#  'fun',
#  'places',
#  'go',
#  "asheville's",
#  'yoga',
#  'centre.',
#  'yoga',
#  'make',
#  'sure',
#  'go,',
#  'even',
#  'once!',
#  "lisa's",
#  'place',
#  'great.',
#  'clean',
#  'lots',
#  'windows.',
#  'bed',
#  'super',
#  'comfortable',
#  'linens',
#  'high',
#  'quality',
#  'made',
#  'cozy',
#  "night's",
#  'sleep.',
#  'wi-fi',
#  'worked',
#  'like',
#  'charm',
#  'enjoyed',
#  'neighborhood',
#  'much,',
#  'place',
#  'within',
#  'walking',
#  'distance',
#  'downtown',
#  'three',
#  'different',
#  'grocery',
#  'stores.',
#  'lisa',
#  'left',
#  'coffee',
#  'us',
#  'delicious.',
#  "we'd",
#  'stay',
#  'visit',
#  'asheville',
#  'future.',
#  'great',
#  'apartment.',
#  'easy',
#  'walk',
#  'town',
#  'shopping.',
#  'like',
#  'outdoor',
#  'space',
#  'back',
#  'deck',
#  'perfect.',
#  'bed',
#  'comfortable,',
#  'large',
#  'bedroom',
#  'bathroom',
#  'everything',
#  'needed',
#  'kitchen.',
#  '<br/>',
#  '<br/>thanks',
#  'lisa',
#  'giving',
#  'us',
#  'great',
#  'fiorst',
#  'intro',
#  'asheville.',
#  '<br/>',
#  '<br/>ellen',
#  'place',
#  'top',
#  'notch',
#  'airbnb',
#  'accommodations.',
#  'adore',
#  'asheville,',
#  'place',
#  'iced',
#  'cake',
#  'recent',
#  'stay.',
#  'clean,',
#  'spacious,',
#  'quiet,',
#  'comfortable,',
#  'close',
#  'everything',
#  'could',
#  'possibly',
#  'want',
#  'need;',
#  'want',
#  'leave!',
#  'really',
#  "can't",
#  'imagine',
#  'anyone',
#  'could',
#  'disappointed',
#  'space.',
#  'perfect,',
#  'quiet',
#  'getaway.',
#  'nice',
#  'neighborhood,',
#  'gorgeous',
#  'city,',
#  'great',
#  'location,',
#  'nice',
#  'people.',
#  'wins',
#  'around.',
#  'super',
#  'comfortable',
#  'charming.',
#  'plenty',
#  'space',
#  'two',
#  'four-legged',
#  'friends.',
#  'great',
#  'getaway.',
#  'perfect',
#  'yard',
#  'lounging,',
#  'reading,',
#  'drinking',
#  'coffee,',
#  'especially',
#  'fun',
#  'dogs!',
#  'location',
#  'convenient',
#  'downtown.',
#  'several',
#  'great',
#  'cafes,',
#  'breweries',
#  'restaurants',
#  'within',
#  'walking/biking',
#  'distance.',
#  'overall,',
#  'enjoyable',
#  'stay',
#  "lisa's",
#  'place.',
#  'clean,',
#  'comfortable,',
#  'cozy,',
#  'nice',
#  'big',
#  'fenced',
#  'yard',
#  'people',
#  'like',
#  'us',
#  'enjoy',
#  'traveling',
#  'dogs.',
#  'two',
#  'issues',
#  'appeared',
#  'result',
#  'problems',
#  'communication',
#  'organization:',
#  '<br/>1.',
#  'meet',
#  'us',
#  'arrived',
#  'left',
#  'alternative',
#  'instructions,',
#  'meant',
#  'wait',
#  'around',
#  'awkwardly',
#  'figure',
#  'supposed',
#  'get',
#  'place.',
#  '<br/>2.',
#  'accused',
#  'us',
#  'told',
#  'dogs,',
#  'clearly',
#  'explained',
#  'first',
#  'email',
#  'sent',
#  'her.',
#  'worked',
#  'end,',
#  'appreciate',
#  'accusatory',
#  'tone.',
#  '<br/>with',
#  'adjustments',
#  'communication',
#  'organization,',
#  "lisa's",
#  'pad',
#  'could',
#  'become',
#  'excellent',
#  'place',
#  'stay',
#  'asheville!',
#  'lisa',
#  'friendly',
#  'accommodating!',
#  'good',
#  'communication',
#  'place',
#  'clean',
#  'super',
#  'cute.',
#  'quick',
#  'walk',
#  'downtown',
#  'area',
#  'lots',
#  'food',
#  'options!',
#  'thanks',
#  'lisa!',
#  'back.',
#  'cozy',
#  'comfortable',
#  'place.',
#  'walking',
#  'distance',
#  'everything',
#  'needed.',
#  'loved',
#  'it!',
#  'stayed',
#  'lisa',
#  'davids',
#  'christmas',
#  'holiday.',
#  'quiet',
#  'comfortable',
#  'apartment',
#  'felt',
#  'like',
#  'getting',
#  'crowd',
#  'short',
#  'walk',
#  'town.',
#  'found',
#  'many',
#  'art',
#  'galleries,',
#  'unique',
#  'shops,',
#  'outstanding',
#  'restaurants.',
#  'spent',
#  'quiet',
#  'evenings',
#  'preparing',
#  'dinners',
#  'apartment.',
#  'though',
#  'kitchen',
#  'small',
#  'minimal,',
#  'everything',
#  'need',
#  'put',
#  'together',
#  'warm,',
#  'delicious',
#  'meal.',
#  '<br/>we',
#  'brought',
#  'jagger,',
#  'yellow',
#  'lab,',
#  'along',
#  'enjoy',
#  'trip',
#  'chance',
#  'meet',
#  'lisa',
#  'davids',
#  'dog,',
#  'lunar.',
#  'hit',
#  'fun',
#  'chasing',
#  'around',
#  'fenced',
#  'yard.',
#  '<br/>lunar',
#  'pleasant',
#  'unexpected',
#  ...]

# %%
fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
word_review_count_df.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Most Frequent Words (All Review)")

plt.show()

# %% [markdown]
# As the rating suggests, most review expresses positive service.
#
# Some of the aspects was mentionted, such as "Great" ,"close","definitely", "Location" , "Recommend" , "perfect" , "Nice","super"

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
#Top 10 common words in the comments with CountVectorizer()
texts= words_review_cleaned

vec = CountVectorizer().fit(texts)
bag_of_words = vec.transform(texts)
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]

cvec_df = pd.DataFrame.from_records(words_freq, columns= ['words', 'counts']).sort_values(by="counts", ascending=False)
cvec_df.head(10)
# Out:
#           words  counts
# 138       great  152374
# 179        stay  127051
# 25        place  123861
# 10    asheville  102029
# 92     location   87073
# 71        clean   80660
# 34     downtown   66374
# 47        would   60540
# 68           br   57264
# 72   everything   54650

# %%
cvec_dict = dict(zip(cvec_df.words, cvec_df.counts))

# %%
from wordcloud import WordCloud

# %%
#Create the word cloud from the file we have 
wordcloud = WordCloud(width=800, height=400)
wordcloud.generate_from_frequencies(frequencies=cvec_dict)
plt.figure( figsize=(20,10) )
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# # Sentiment Analysis to detect good/bad Reviews
# Sentiment analysis is the process of identifying people's attitude and emotional states from a language.
#
# In the application, it able to classify good/bad reviews.
#
# It is a technique uses for natural language processing to interpret and classify emotions.
#
# The output would summarize the positive, negative, or neutral sentiment of these reviews.
#
# But it's easier for us to find a bad review using this approach when there's a lot of data

# %%
   nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\swathi
# [nltk_data]     veldanda\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
reviews_f = [r for r in df23['comments'] if pd.notnull(r)] 

pscores = [sid.polarity_scores(comment) for comment in reviews_f]

# %%
#Histogram plot neutral
pd.Series([score['compound'] for score in pscores]).plot(kind='hist')

plt.title('Compound Scores')
plt.xlabel('Scores')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
#Histogram plot neutral
pd.Series([score['neu'] for score in pscores]).plot(kind='hist')

plt.title('Neutral Scores')
plt.xlabel('Scores')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
#Histogram plot positive
pd.Series([score['pos'] for score in pscores]).plot(kind='hist')

plt.title('Positive Scores')
plt.xlabel('Scores')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
#Histogram plot negative
pd.Series([score['neg'] for score in pscores]).plot(kind='hist', bins=100)

plt.title('Negative Scores')
plt.xlabel('Scores')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# The negative scores was mostly zero.
#
# This implies that indeed the experience was pleasant for most Airbnb stay.

# %%
#Create dataframe for sentiment analysis
scored_reviews = pd.DataFrame()
scored_reviews['review'] = [r for r in reviews_f if pd.notnull(r)]
scored_reviews['compound'] = [score['compound'] for score in pscores]
scored_reviews['negativity'] = [score['neg'] for score in pscores]
scored_reviews['neutrality'] = [score['neu'] for score in pscores]
scored_reviews['positivity'] = [score['pos'] for score in pscores]

# %% [markdown]
# # Inspecting Bad review

# %%
print(scored_reviews.shape)
# Out:
# (246946, 5)

# %%
scored_reviews.query('positivity > 0')
# Out:
#                                                    review  compound  \
# 0       Lisa is superb hostess, she will treat you lik...    0.9741
# 1       This was a lovely little place walking distanc...    0.9071
# 2       Lisa was very nice to work with.  However, we ...    0.9434
# 3       I feel very lucky to have found this beautiful...    0.9988
# 4       Great roomy little apartment, beautiful privat...    0.9117
# ...                                                   ...       ...
# 246941               Lovely home, v convenient location!!    0.6580
# 246942  This Airbnb was a great fit for us for a famil...    0.9586
# 246943  Great place, great host, & not one bad thing t...    0.9011
# 246944  Wonderful hosts, excellent communication, grea...    0.9100
# 246945  Beautiful, brand new, and private cabin. Compl...    0.9594
#
#         negativity  neutrality  positivity
# 0            0.000       0.690       0.310
# 1            0.000       0.569       0.431
# 2            0.000       0.892       0.108
# 3            0.009       0.584       0.407
# 4            0.066       0.577       0.357
# ...            ...         ...         ...
# 246941       0.000       0.406       0.594
# 246942       0.000       0.703       0.297
# 246943       0.000       0.388       0.612
# 246944       0.000       0.410       0.590
# 246945       0.000       0.688       0.312
#
# [243504 rows x 5 columns]

# %%
scored_reviews.query('negativity > 0')
# Out:
#                                                    review  compound  \
# 3       I feel very lucky to have found this beautiful...    0.9988
# 4       Great roomy little apartment, beautiful privat...    0.9117
# 8       The place was super cute and clean with a grea...    0.9821
# 10      We stayed at Lisa/David's place for a long Bel...    0.9580
# 12      We found this sweet spot last minute when we w...    0.9828
# ...                                                   ...       ...
# 246932  We had an amazing stay at Kelly's place early ...    0.9955
# 246934  We had a great stay!  The owners communicated ...    0.8775
# 246936  This home was amazing for our family. The hous...    0.9800
# 246938  This is a perfect spot for a couple looking to...    0.9352
# 246940  This home was perfect for our impromptu trip t...    0.9672
#
#         negativity  neutrality  positivity
# 3            0.009       0.584       0.407
# 4            0.066       0.577       0.357
# 8            0.032       0.756       0.212
# 10           0.049       0.760       0.191
# 12           0.050       0.650       0.299
# ...            ...         ...         ...
# 246932       0.010       0.800       0.189
# 246934       0.033       0.800       0.167
# 246936       0.027       0.679       0.294
# 246938       0.040       0.659       0.301
# 246940       0.025       0.719       0.255
#
# [42762 rows x 5 columns]

# %%
scored_reviews.query('negativity > positivity')
# Out:
#                                                    review  compound  \
# 58      Lovely little place for a weekend getaway! No ...   -0.0880
# 174     We were dissapointed with the cottage.  When w...   -0.7290
# 187     Great location in Asheville! Basic but clean c...   -0.1386
# 232                                      Not satisfactory   -0.2755
# 420     Was 100% happy with our stay. We got there ear...   -0.1189
# ...                                                   ...       ...
# 246847                                         No comment   -0.2960
# 246851             No shampoo/conditioner/soap in showers   -0.2960
# 246861  As a management company, TurnKey Vacation Rent...   -0.0818
# 246888                                         No comment   -0.2960
# 246892             No shampoo/conditioner/soap in showers   -0.2960
#
#         negativity  neutrality  positivity
# 58           0.186       0.695       0.119
# 174          0.095       0.878       0.027
# 187          0.280       0.463       0.257
# 232          0.678       0.322       0.000
# 420          0.173       0.703       0.124
# ...            ...         ...         ...
# 246847       0.688       0.312       0.000
# 246851       0.423       0.577       0.000
# 246861       0.093       0.822       0.086
# 246888       0.688       0.312       0.000
# 246892       0.423       0.577       0.000
#
# [1794 rows x 5 columns]

# %%
negative_reviews=scored_reviews.query('negativity > positivity').query('compound > 0.2')
print(negative_reviews.shape)
negative_reviews.head()
# Out:
# (51, 5)
#                                                   review  compound  \
# 15739  This was my first experience with Airbnb, and ...    0.2695
# 20036  First, Ellen meets you downstairs, she was ver...    0.2567
# 34713  The GR Inn is very considerate of all your nee...    0.2300
# 36364  If you’re planning a trip in the Asheville are...    0.2779
# 39128  The host was responsive, which was great. We h...    0.4310
#
#        negativity  neutrality  positivity
# 15739       0.113       0.800       0.087
# 20036       0.089       0.828       0.083
# 34713       0.124       0.773       0.103
# 36364       0.132       0.744       0.124
# 39128       0.158       0.686       0.156

# %% [markdown]
# only a small fraction of reviews are negative

# %% [markdown]
# We have looked at some extreme cases where there's a lack of accuracy in the score.
# overall Sentiment performance was good
